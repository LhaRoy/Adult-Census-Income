# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('adult.csv')

# %%
df.sample(5)
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 20665   46       Federal-gov  106252  Some-college             10
# 3295    43           Private  313022       HS-grad              9
# 26050   27           Private  289147     Bachelors             13
# 24150   29         State-gov  243875     Assoc-voc             11
# 1623    59  Self-emp-not-inc  165315     Bachelors             13
#
#            marital.status         occupation   relationship   race     sex  \
# 20665            Divorced       Adm-clerical  Not-in-family  White  Female
# 3295   Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 26050       Never-married     Prof-specialty      Own-child  White  Female
# 24150            Divorced       Adm-clerical      Own-child  White    Male
# 1623   Married-civ-spouse     Prof-specialty        Husband  White    Male
#
#        capital.gain  capital.loss  hours.per.week native.country income
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
for col in df:
    print(f"Value Counts dari Kolom {col}")
    print(df[col].value_counts())
    print("")
# Out:
# Value Counts dari Kolom age
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: age, Length: 73, dtype: int64
#
# Value Counts dari Kolom workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
#
# Value Counts dari Kolom fnlwgt
# 123011    13
# 203488    13
# 164190    13
# 126675    12
# 121124    12
#           ..
# 36376      1
# 78567      1
# 180407     1
# 210869     1
# 125489     1
# Name: fnlwgt, Length: 21648, dtype: int64
#
# Value Counts dari Kolom education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# ...

# %%
# Cek total dari "?" pada setiap kolom karena cara diatas terlalu panjang kalau hanya ingin melihat value `?` pada setiap kolom

for i in df.columns:
    t = df[i].value_counts()
    index = list(t.index)
    print("Total `?` pada kolom", i)
    for i in index:
        temp = 0
        if i == "?":
            print(t['?'])
            temp = 1
            break
    if temp == 0:
        print("0")
# Out:
# Total `?` pada kolom age
# 0
# Total `?` pada kolom workclass
# 1836
# Total `?` pada kolom fnlwgt
# 0
# Total `?` pada kolom education
# 0
# Total `?` pada kolom education.num
# 0
# Total `?` pada kolom marital.status
# 0
# Total `?` pada kolom occupation
# 1843
# Total `?` pada kolom relationship
# 0
# Total `?` pada kolom race
# 0
# Total `?` pada kolom sex
# 0
# Total `?` pada kolom capital.gain
# 0
# Total `?` pada kolom capital.loss
# 0
# Total `?` pada kolom hours.per.week
# 0
# Total `?` pada kolom native.country
# 583
# Total `?` pada kolom income
# 0

# %% [markdown]
# ### Kolom yang mempunyai nilai `?` adalah kolom `workclass`,`occupation` dan `native.country`

# %% [markdown]
# ### total nilai `?` dari kolom `workclass`,`occupation` dan `native.country` adalah 1836+1843+583 = 4262 ==> 13.089% dari data [32561]

# %% [markdown]
# ### Karena Data yang kosong tidak terlalu banyak, disini saya merubah value `?` dengan NaN dan setelah itu saya drop value NaN nya

# %%
data_df = df.replace('?', np.nan)

# %%
data_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90       NaN   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66       NaN  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
data_df.isna().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %% [markdown]
# ### Sekarang terlihat ada beberapa data yang NaN sesuai dugaan terprediksi di atas --> 13% data berupa NaN, setelah ini saya akan mulai DROP data NaN

# %%
data_df = data_df.dropna()

# %%
data_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country income
# 1          4356              18  United-States  <=50K
# ...

# %%
#Cek apakah masih ada data yang NaN

data_df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %% [markdown]
# ### Data NaN sudah tidak ada, data sudah bersih dari Data Missing

# %%
data_df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  30162.000000  3.016200e+04   30162.000000  30162.000000  30162.000000
# mean      38.437902  1.897938e+05      10.121312   1092.007858     88.372489
# std       13.134665  1.056530e+05       2.549995   7406.346497    404.298370
# min       17.000000  1.376900e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.176272e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.784250e+05      10.000000      0.000000      0.000000
# 75%       47.000000  2.376285e+05      13.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    30162.000000
# mean        40.931238
# std         11.979984
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data_df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
data_df['income_data'] = data_df['income'].map({'>50K' : 1, '<=50K' : 0})
data_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country income  income_data
# 1          4356              18  United-States  <=50K            0
# ...

# %%
data_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country income  income_data
# 1          4356              18  United-States  <=50K            0
# ...

# %%
data_df.drop(labels=["income"], axis = 1, inplace = True)

# %%
data_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country  income_data
# 1          4356              18  United-States            0
# ...

# %% [raw]
# !!!CATATAN!!!
#
# Relasi education dengan education.num
#
#
# 9     10501 HS-grad         |  1 => Preschool = 51
# 10     7291 Some-college    |  2 => 1st-4th   = 168
# 13     5355 Bachelors       |  3 => 5th-6th   = 333
# 14     1723 Masters         |  4 => 7th-8th   = 646
# 11     1382 Assoc-voc       |  5 => 9th       = 514
# 7      1175 11th            |  6 => 10th      = 933
# 12     1067 Assoc-acdm      |  7 => 11th      = 1175
# 6       933 10th            |  8 => 12th      = 433
# 4       646 7th-8th         |  9 => HS-grad   = 10501
# 15      576 Prof-school     |  10 => Some-college = 7291
# 5       514 9th             |  11 => Assoc-voc = 1382
# 8       433 12th            |  12 => Assoc-acdm = 1067
# 16      413 Doctorate       |  13 => Bachelors = 5355
# 3       333 5th-6th         |  14 => Masters  = 1723
# 2       168 1st-4th         |  15 => Prof-school = 576
# 1        51 Preschool       |  16 => Doctorate = 413
#
#
# sepertinya dari data berikut mungkin bisa lebih memilih kolom 'education.num' sebagai perwakilan dari kolom education
#
#
# Value Counts dari Kolom workclass ==> BAGIAN INI DI UBAH MENGGUNAKAN ONE HOT ENDCODING
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
#
# dari data workclass yang adalah cats bisa dijadikan nums, dengan pembagian:
# drop baris yang mengandung "Without-pay" dan "Never-worked" karena tidak terlalu banyak datanya dan tidak mengurangi value data secara signifikan
#
# 0 => yang bekerja di pemerintahan [Local-gov, State-gov, Federal-gov]
# 1 => yang bekerja di perusahaan swasta [Private]
#
#
# Value Counts dari Kolom marital.status ==> BAGIAN INI DI UBAH MENGGUNAKAN ONE HOT ENCODIGN
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital.status, dtype: int64
#
# dari data marital.status yang adalah cats bisa dijadikan nums, dengan pembagian:
#
# menikah = 1
# single = 0
#
# ['Never-married','Divorced','Separated','Widowed'] ==> single
# ['Married-civ-spouse','Married-spouse-absent','Married-AF-spouse'] ==> menikah
#
#
# Value Counts dari Kolom sex
# Male      21790
# Female    10771
# Name: sex, dtype: int64
#
# dari data sex yang adalah cats bisa dijadikan nums, dengan pembagian:
#
# Male = 0
# Female = 1
#
#
# ==>> RACE DI UBAH MENGGUNAKAN ONE HOT ENCODING
#
#
# TOTAL ADA 3 CATS YANG DAPAT DI RUBAH DARI CATS KE NUMS

# %% [markdown]
# ###

# %% [markdown]
# ### rubah kolom sex :  male jadi 0 dan female jadi 1

# %%
data_df["sex"] = data_df["sex"].map({"Male": 0, "Female":1})

# %% [markdown]
# ### menghilangkan row yang mengandung without-pay dari workclass

# %%
data_df = data_df[data_df.workclass != 'Without-pay']

# %% [markdown]
# ### menghilangkan row yang mengandung never-worked dari workclass

# %%
data_df = data_df[data_df.workclass != 'Never-worked']

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30148 entries, 1 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30148 non-null  int64
#  1   workclass       30148 non-null  object
#  2   fnlwgt          30148 non-null  int64
#  3   education       30148 non-null  object
#  4   education.num   30148 non-null  int64
#  5   marital.status  30148 non-null  object
#  6   occupation      30148 non-null  object
#  7   relationship    30148 non-null  object
#  8   race            30148 non-null  object
#  9   sex             30148 non-null  int64
#  10  capital.gain    30148 non-null  int64
#  11  capital.loss    30148 non-null  int64
#  12  hours.per.week  30148 non-null  int64
#  13  native.country  30148 non-null  object
#  14  income_data     30148 non-null  int64
# dtypes: int64(8), object(7)
# memory usage: 3.7+ MB

# %%
data_df['workclass'].value_counts()
# Out:
# Private             22286
# Self-emp-not-inc     2499
# Local-gov            2067
# State-gov            1279
# Self-emp-inc         1074
# Federal-gov           943
# Name: workclass, dtype: int64

# %%
data_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race  sex  capital.gain  capital.loss  \
# 1    Exec-managerial  Not-in-family  White    1             0          4356
# 3  Machine-op-inspct      Unmarried  White    1             0          3900
# 4     Prof-specialty      Own-child  White    1             0          3900
# 5      Other-service      Unmarried  White    1             0          3770
# 6       Adm-clerical      Unmarried  White    0             0          3770
#
#    hours.per.week native.country  income_data
# 1              18  United-States            0
# ...

# %%
# onehots code untuk workclass

workclass = pd.get_dummies(data_df['workclass'])

# %%
# onehots code untuk marital.status

marital_status = pd.get_dummies(data_df['marital.status'])

# %%
# onehots code untuk race

race = pd.get_dummies(data_df['race'])

# %%
data_df = pd.concat([data_df, workclass, marital_status, race], axis = 1)

# %%
# data set yang sudah lengkap dan bersih

data_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race  sex  ...  Married-civ-spouse  \
# 1    Exec-managerial  Not-in-family  White    1  ...                   0
# 3  Machine-op-inspct      Unmarried  White    1  ...                   0
# 4     Prof-specialty      Own-child  White    1  ...                   0
# 5      Other-service      Unmarried  White    1  ...                   0
# 6       Adm-clerical      Unmarried  White    0  ...                   0
#
#    Married-spouse-absent  Never-married Separated  Widowed  \
# ...

# %%
data_df.drop_duplicates()
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 1       82   Private  132870       HS-grad              9             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# 5       34   Private  216864       HS-grad              9            Divorced
# 6       38   Private  150601          10th              6           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
data_df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income_data', 'Federal-gov', 'Local-gov', 'Private', 'Self-emp-inc',
#        'Self-emp-not-inc', 'State-gov', 'Divorced', 'Married-AF-spouse',
#        'Married-civ-spouse', 'Married-spouse-absent', 'Never-married',
#        'Separated', 'Widowed', 'Amer-Indian-Eskimo', 'Asian-Pac-Islander',
#        'Black', 'Other', 'White'],
#       dtype='object')

# %%
data_df.dtypes
# Out:
# age                       int64
# workclass                object
# fnlwgt                    int64
# education                object
# education.num             int64
# marital.status           object
# occupation               object
# relationship             object
# race                     object
# sex                       int64
# capital.gain              int64
# capital.loss              int64
# hours.per.week            int64
# native.country           object
# income_data               int64
# Federal-gov               uint8
# Local-gov                 uint8
# Private                   uint8
# Self-emp-inc              uint8
# Self-emp-not-inc          uint8
# State-gov                 uint8
# Divorced                  uint8
# Married-AF-spouse         uint8
# Married-civ-spouse        uint8
# Married-spouse-absent     uint8
# Never-married             uint8
# Separated                 uint8
# Widowed                   uint8
# Amer-Indian-Eskimo        uint8
# ...

# %% [raw]
# Local-gov, Private Self-emp-inc, Self-emp-not-inc, State-gov, Divorced, Married-AF-spouse, Married-civ-spouse, Married-spouse-absent, Never-married, Separated, Widowed, Amer-Indian-Eskimo, Asian-Pac-Islander, Black, Other, White

# %%
# cats dan nums sudah diperbaharui disini

nums = ['age', 'fnlwgt', 'education.num', 'sex', 'capital.gain', 'capital.loss', 'hours.per.week', 'income_data', 'Federal-gov', 'Local-gov', 'Private', 'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Divorced', 'Married-AF-spouse', 'Married-civ-spouse', 'Married-spouse-absent', 'Never-married', 'Separated', 'Widowed', 'Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White']

cats = ['workclass','marital.status', 'occupation', 'relationship', 'race', 'native.country']

# %%
### Cek lagi Corelation dari numerical values

plt.figure(figsize=(30, 20))
cek_dong = sns.heatmap(data_df[nums].corr(), annot = True, fmt = '.2f', cmap = 'coolwarm')

# %% [markdown]
# ### `income_data` sangat berkorelasi dengan `Married-civ-spouse`, `education.num`, `age`, `hours.per.week`, `capital.gain`, dan `capital.loss`

# %% [markdown]
# ###

# %% [markdown]
# ### Cek Jumlah Income >50K dan <=50K

# %%
plt.rcParams['figure.figsize'] = [10,8]
ax = sns.countplot(data = data_df, x = 'income_data')

plt.text(-0.11, 22700, '<=50K', fontsize = 15)
plt.text(0.91, 7600, '>50K', fontsize = 15)

plt.title('Perbandingan Jumlah Income >50K dan <=50K', fontsize = 15);

# %% [markdown]
# ### Ternyata banyak juga yang income nya kurang dari 50K!!!!

# %% [markdown]
# ###

# %% [markdown]
# ## Cek antara Education terhadap Income

# %%
g = sns.barplot(x = 'education', y = 'income_data', data = data_df)
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('Perbandingan Income terhadap Education', fontsize = 15)

plt.savefig('perbandingan income terhadap education.png');

# %% [markdown]
# ###

# %% [markdown]
# ## Cek Antara Capital.gain terhadap Income

# %%
data_df[['capital.gain', 'capital.loss', 'White', 'Black']].head(30)
# Out:
#     capital.gain  capital.loss  White  Black
# 1              0          4356      1      0
# 3              0          3900      1      0
# 4              0          3900      1      0
# 5              0          3770      1      0
# 6              0          3770      1      0
# 7              0          3683      1      0
# 8              0          3683      1      0
# 10             0          3004      0      1
# 11             0          2824      1      0
# 12             0          2824      1      0
# 13             0          2824      1      0
# 15             0          2824      1      0
# 16             0          2824      1      0
# 17             0          2824      1      0
# 19             0          2824      1      0
# 20             0          2824      1      0
# 21             0          2754      1      0
# 22             0          2754      1      0
# 23             0          2603      1      0
# 25             0          2603      1      0
# ...

# %%
data_df['White'].value_counts()
# Out:
# 1    25921
# 0     4227
# Name: White, dtype: int64

# %%
data_df['Black'].value_counts()
# Out:
# 0    27332
# 1     2816
# Name: Black, dtype: int64

# %%
data_df['capital.gain'].value_counts()
# Out:
# 0        27612
# 15024      337
# 7688       270
# 7298       240
# 99999      148
#          ...
# 401          1
# 22040        1
# 4931         1
# 1455         1
# 1639         1
# Name: capital.gain, Length: 118, dtype: int64

# %%
data_df['capital.gain'].describe()
# Out:
# count    30148.000000
# mean      1092.288411
# std       7408.005326
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital.gain, dtype: float64

# %%
data_df['capital.loss'].value_counts()
# Out:
# 0       28721
# 1902      194
# 1977      162
# 1887      155
# 1848       50
#         ...
# 419         1
# 1411        1
# 1539        1
# 2472        1
# 2467        1
# Name: capital.loss, Length: 90, dtype: int64

# %%
data_df['capital.loss'].describe()
# Out:
# count    30148.000000
# mean        88.413527
# std        404.387750
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capital.loss, dtype: float64

# %%
data_black = data_df.loc[(data_df.Black == 1) & (data_df['capital.gain'])]

# %%
data_black_true = data_black[['capital.gain', 'capital.loss', 'Black', 'income_data']]

# %%
data_black_true.head(10)
# Out:
#       capital.gain  capital.loss  Black  income_data
# 1547         99999             0      1            1
# 1570         99999             0      1            1
# 1593         99999             0      1            1
# 1653         99999             0      1            1
# 1665         99999             0      1            1
# 1672         99999             0      1            1
# 1746         20051             0      1            1
# 1765         20051             0      1            1
# 1769         20051             0      1            1
# 2935          6849             0      1            0

# %%
data_white = data_df.loc[(data_df.White == 1) & (data_df['capital.gain'])]

# %%
data_white_true = data_white[['capital.gain', 'capital.loss', 'White', 'income_data']]

# %%
data_black_true
# Out:
#       capital.gain  capital.loss  Black  income_data
# 1547         99999             0      1            1
# 1570         99999             0      1            1
# 1593         99999             0      1            1
# 1653         99999             0      1            1
# 1665         99999             0      1            1
# 1672         99999             0      1            1
# 1746         20051             0      1            1
# 1765         20051             0      1            1
# 1769         20051             0      1            1
# 2935          6849             0      1            0
# 2959          6497             0      1            0
# 2960          6497             0      1            0
# 2962          6497             0      1            0
# 2965          6497             0      1            0
# 2990          5455             0      1            0
# 2991          5455             0      1            0
# 2996          5455             0      1            0
# ...

# %%
data_black_true.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 1547 to 4170
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   capital.gain  58 non-null     int64
#  1   capital.loss  58 non-null     int64
#  2   Black         58 non-null     uint8
#  3   income_data   58 non-null     int64
# dtypes: int64(3), uint8(1)
# memory usage: 1.9 KB

# %%
data_black_true.describe()
# Out:
#        capital.gain  capital.loss  Black  income_data
# count     58.000000          58.0   58.0    58.000000
# mean   14551.655172           0.0    1.0     0.258621
# std    29532.671565           0.0    0.0     0.441701
# min     1055.000000           0.0    1.0     0.000000
# 25%     3008.500000           0.0    1.0     0.000000
# 50%     3834.000000           0.0    1.0     0.000000
# 75%     5455.000000           0.0    1.0     0.750000
# max    99999.000000           0.0    1.0     1.000000

# %%
data_white_true
# Out:
#       capital.gain  capital.loss  White  income_data
# 1519         99999             0      1            1
# 1521         99999             0      1            1
# 1522         99999             0      1            1
# 1523         99999             0      1            1
# 1524         99999             0      1            1
# ...            ...           ...    ...          ...
# 4175          1055             0      1            0
# 4178           991             0      1            0
# 4179           991             0      1            0
# 4180           991             0      1            0
# 4223           401             0      1            0
#
# [733 rows x 4 columns]

# %%
data_white_true.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 733 entries, 1519 to 4223
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   capital.gain  733 non-null    int64
#  1   capital.loss  733 non-null    int64
#  2   White         733 non-null    uint8
#  3   income_data   733 non-null    int64
# dtypes: int64(3), uint8(1)
# memory usage: 23.6 KB

# %%
data_white_true.describe()
# Out:
#        capital.gain  capital.loss  White  income_data
# count    733.000000         733.0  733.0   733.000000
# mean   22098.579809           0.0    1.0     0.386085
# std    36940.151469           0.0    0.0     0.487183
# min      401.000000           0.0    1.0     0.000000
# 25%     3103.000000           0.0    1.0     0.000000
# 50%     3471.000000           0.0    1.0     0.000000
# 75%     7443.000000           0.0    1.0     1.000000
# max    99999.000000           0.0    1.0     1.000000

# %%
dt_vis_black_true = data_black_true['capital.gain'].sum()

# %%
dt_vis_black_true
# Out:
# 843996

# %%
data_black_true['capital.loss'].sum()
# Out:
# 0

# %%
dt_vis_white_true = data_white_true['capital.gain'].sum()

# %%
dt_vis_white_true
# Out:
# 16198259

# %%
data_white_true['capital.loss'].sum()
# Out:
# 0

# %%
plt.rcParams['figure.figsize'] = [10,8]
ax1 = sns.countplot(data = data_black_true, x = 'Black', color='red')

# %%
plt.rcParams['figure.figsize'] = [10,8]
ax2 = sns.countplot(data = data_white_true, x = 'White', color= 'green')

# %%
index = ['Black', 'White']

race = {'Total_Capital_Gain_Black_Race': [843996],
        'Total_Capital_Gain_White_Race': [16198259]
        }

cap_gain_total = pd.DataFrame(race, columns = ['Total_Capital_Gain_Black_Race', 'Total_Capital_Gain_White_Race'])

# %%
cap_gain_total
# Out:
#    Total_Capital_Gain_Black_Race  Total_Capital_Gain_White_Race
# 0                         843996                       16198259

# %%
cap_gain_total.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
cap_gain_total.plot(kind='bar')

plt.text(-0.17, 1000000, '$ 843.996', fontsize = 20)
plt.text(0.07, 16350000, '$ 16.198.259', fontsize = 20)

plt.xlabel('Capital Gain', fontsize = 18)
plt.ylabel('In Million Dollar', fontsize = 18)

plt.title('Total Capital Gain', fontsize = 25)

plt.savefig('totalcapitalgain.png');

# %% [markdown]
# ###

# %% [markdown]
# ### Cek income terhadapat Race

# %%
sns.countplot(x = 'race', hue = 'income_data', data = data_df)
plt.xlabel('race', fontsize = 13)
plt.ylabel('income', fontsize = 13)

plt.text(-0.40, 19200, '<=50K', fontsize = 13)
plt.text(0.03, 7000, '>50K', fontsize = 13)

plt.text(0.58, 2500, '<=50K', fontsize = 13)
plt.text(1, 500, '>50K', fontsize = 13)

plt.text(1.58, 680, '<=50K', fontsize = 13)
plt.text(2.03, 500, '>50K', fontsize = 13)

plt.text(2.55, 300, '<=50K', fontsize = 13)
plt.text(3.05, 200, '>50K', fontsize = 13)

plt.text(3.58, 300, '<=50K', fontsize = 13)
plt.text(4.05, 100, '>50K', fontsize = 13)

plt.title('Perbandingan Income >50K dan <=50K terhadap Race', fontsize = 15);

# %%
workclass_black.head()
# Out:
#      age         workclass  fnlwgt     education  education.num  \
# 10    45           Private  172274     Doctorate             16
# 34    60  Self-emp-not-inc  205246       HS-grad              9
# 125   27           Private  156516  Some-college             10
# 134   52           Private  222405       HS-grad              9
# 145   61           Private   43554       5th-6th              3
#
#          marital.status         occupation   relationship   race  sex  ...  \
# 10             Divorced     Prof-specialty      Unmarried  Black    1  ...
# 34        Never-married    Exec-managerial  Not-in-family  Black    0  ...
# 125  Married-civ-spouse       Adm-clerical           Wife  Black    1  ...
# 134  Married-civ-spouse              Sales        Husband  Black    0  ...
# 145       Never-married  Handlers-cleaners  Not-in-family  Black    0  ...
#
#      Married-civ-spouse  Married-spouse-absent  Never-married Separated  \
# ...

# %%
workclass_white['income_data'].value_counts()
# Out:
# 0    19082
# 1     6839
# Name: income_data, dtype: int64

# %%
white = 19082/(19082 + 6839)

# %%
white * 100
# Out:
# 73.61598703753714

# %%
workclass_black['income_data'].value_counts()
# Out:
# 0    2450
# 1     366
# Name: income_data, dtype: int64

# %%
black = 2450/(2450+366)

# %%
black * 100
# Out:
# 87.0028409090909

# %% [raw]
# Persentase black lebih banyak <=50K

# %%
persentase = pd.DataFrame({
    'Black' : [87],
    'White' : [73]
})

# %%
persentase
# Out:
#    Black  White
# 0     87     73

# %%
persentase.plot(kind='bar')
plt.xlabel('Race', fontsize = 15)
plt.ylabel('Percentase', fontsize = 15)

plt.text(-0.14, 88, '87%', fontsize = 15)
plt.text(0.11, 74, '73%', fontsize = 15)

plt.title('Persentase Income <=50K Black Race & White Race', fontsize = 25)

plt.savefig('persentase income <=50K black race & white race.png', bbox_inches = 'tight');

# %% [markdown]
# ###

# %% [markdown]
# ### Cek income terhadapat age

# %%
g = sns.barplot(x = 'age', y = 'income_data', data = data_df)
fig = plt.gcf()
fig.set_size_inches(25,12)

# %% [markdown]
# ###

# %% [markdown]
# ### Cek Education Terhadap Race

# %%
g = sns.catplot(x = 'race', y = "education.num", data=data_df, kind="bar", height = 6, palette = "muted")
g.despine(left=True)
g = g.set_ylabels("education")
plt.title('Perbandingan antara Education terhadapat Race', fontsize = 15)

plt.savefig('perbandigan educataion terhadap race.png', bbox_inches = 'tight');

# %% [markdown]
# ###

# %% [markdown]
# ### Cek Education Terhadapat Race

# %%
data_df.loc[(data_df.Black == 1) & (data_df['education'])]
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 10      45           Private  172274     Doctorate             16
# 34      60  Self-emp-not-inc  205246       HS-grad              9
# 125     27           Private  156516  Some-college             10
# 134     52           Private  222405       HS-grad              9
# 145     61           Private   43554       5th-6th              3
# ...    ...               ...     ...           ...            ...
# 32516   25         Local-gov  514716     Bachelors             13
# 32519   40           Private  142657     Assoc-voc             11
# 32524   33           Private  273243       HS-grad              9
# 32538   22           Private  325033          12th              8
# 32540   30           Private  345898       HS-grad              9
#
#            marital.status         occupation   relationship   race  sex  ...  \
# 10               Divorced     Prof-specialty      Unmarried  Black    1  ...
# ...

# %%
education_black = data_df.loc[(data_df.Black == 1) & (data_df['education'])]

# %%
education_white = data_df.loc[(data_df.White == 1) & (data_df['education'])]

# %%
education_black['education'].value_counts()
# Out:
# HS-grad         1060
# Some-college     687
# Bachelors        301
# 11th             128
# 10th             119
# Assoc-voc        108
# Assoc-acdm       100
# Masters           78
# 9th               77
# 12th              51
# 7th-8th           49
# 5th-6th           18
# Prof-school       15
# 1st-4th           13
# Doctorate          8
# Preschool          4
# Name: education, dtype: int64

# %%
education_white['education'].value_counts()
# Out:
# HS-grad         8394
# Some-college    5702
# Bachelors       4448
# Masters         1458
# Assoc-voc       1142
# 11th             882
# Assoc-acdm       865
# 10th             668
# Prof-school      486
# 7th-8th          475
# 9th              359
# Doctorate        338
# 12th             306
# 5th-6th          242
# 1st-4th          123
# Preschool         33
# Name: education, dtype: int64

# %%
sns.countplot(x = 'Black', hue = 'education', data = education_black)
plt.xlabel('Education', fontsize = 13)
plt.ylabel('Black Race', fontsize = 13)
plt.title('Education Black Race', fontsize = 15);

# %%
sns.countplot(x = 'White', hue = 'education', data = education_white)
plt.xlabel('Education', fontsize = 13)
plt.ylabel('White Race', fontsize = 13)
plt.title('Education White Race', fontsize = 15);

# %%
education_black['education'].value_counts(normalize=True).plot(kind='barh', color = 'red')
plt.xlabel('Black Race', fontsize = 15)
plt.ylabel('Education', fontsize = 15)
plt.title('Black Race Education', fontsize = 20)

plt.savefig('black race education.png');

# %%
education_white['education'].value_counts(normalize=True).plot(kind='barh')
plt.xlabel('White Race', fontsize = 15)
plt.ylabel('Education', fontsize = 15)
plt.title('White Race Education', fontsize = 20)

plt.savefig('white race education.png');

# %% [markdown]
# ###

# %% [markdown]
# ### Cek Pekerjaan terhadap Race

# %%
data_df.loc[(data_df.Black == 1) & (data_df['occupation'])]
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 10      45           Private  172274     Doctorate             16
# 34      60  Self-emp-not-inc  205246       HS-grad              9
# 125     27           Private  156516  Some-college             10
# 134     52           Private  222405       HS-grad              9
# 145     61           Private   43554       5th-6th              3
# ...    ...               ...     ...           ...            ...
# 32516   25         Local-gov  514716     Bachelors             13
# 32519   40           Private  142657     Assoc-voc             11
# 32524   33           Private  273243       HS-grad              9
# 32538   22           Private  325033          12th              8
# 32540   30           Private  345898       HS-grad              9
#
#            marital.status         occupation   relationship   race  sex  ...  \
# 10               Divorced     Prof-specialty      Unmarried  Black    1  ...
# ...

# %%
workclass_black = data_df.loc[(data_df.Black == 1) & (data_df['workclass'])]

# %%
workclass_white = data_df.loc[(data_df.White == 1) & (data_df['workclass'])]

# %%
workclass_black['workclass'].value_counts()
# Out:
# Private             2100
# Local-gov            282
# Federal-gov          168
# State-gov            156
# Self-emp-not-inc      87
# Self-emp-inc          23
# Name: workclass, dtype: int64

# %%
workclass_white['workclass'].value_counts()
# Out:
# Private             19137
# Self-emp-not-inc     2314
# Local-gov            1704
# State-gov            1050
# Self-emp-inc         1006
# Federal-gov           710
# Name: workclass, dtype: int64

# %%
workclass_black['workclass'].value_counts(normalize=False).plot(kind='barh', color = 'red')
plt.xlabel('Black Race', fontsize = 15)
plt.ylabel('Workclass', fontsize = 15)
plt.title('Black Race Workclass', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Black Race Workclass')

# %%
workclass_white['workclass'].value_counts(normalize=False).plot(kind='barh')
plt.xlabel('White Race', fontsize = 15)
plt.ylabel('Education', fontsize = 15)
plt.title('White Race Workclass', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'White Race Workclass')

# %%
workclass_black['occupation'].value_counts(normalize=False).plot(kind='barh', color = 'red')
plt.xlabel('Black Race', fontsize = 15)
plt.ylabel('Occupation', fontsize = 15)
plt.title('Black Race Occupation', fontsize = 20)

plt.savefig('black race occupation normalize off.png');

# %%
workclass_white['occupation'].value_counts(normalize=False).plot(kind='barh')
plt.xlabel('White Race', fontsize = 15)
plt.ylabel('Occupation', fontsize = 15)
plt.title('White Race Occupation', fontsize = 20)

plt.savefig('white race occupation normalize off.png');

# %%
workclass_black.loc[workclass_black['income_data'] == 1]
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 10      45           Private  172274     Doctorate             16
# 34      60  Self-emp-not-inc  205246       HS-grad              9
# 235     65       Federal-gov   23494  Some-college             10
# 369     32           Private  295589       Masters             14
# 388     57         Local-gov  174132       Masters             14
# ...    ...               ...     ...           ...            ...
# 31682   45           Private  151267     Bachelors             13
# 31732   54           Private  229272       HS-grad              9
# 31815   43           Private  169628     Bachelors             13
# 31841   38         Local-gov  161463   Prof-school             15
# 31843   57       Federal-gov   62020   Prof-school             15
#
#            marital.status       occupation   relationship   race  sex  ...  \
# 10               Divorced   Prof-specialty      Unmarried  Black    1  ...
# ...

# %%
workclass_black.loc[workclass_black['income_data'] == 0]
# Out:
#        age  workclass  fnlwgt     education  education.num  \
# 125     27    Private  156516  Some-college             10
# 134     52    Private  222405       HS-grad              9
# 145     61    Private   43554       5th-6th              3
# 151     59  Local-gov  171328       HS-grad              9
# 156     42    Private  191765       HS-grad              9
# ...    ...        ...     ...           ...            ...
# 32516   25  Local-gov  514716     Bachelors             13
# 32519   40    Private  142657     Assoc-voc             11
# 32524   33    Private  273243       HS-grad              9
# 32538   22    Private  325033          12th              8
# 32540   30    Private  345898       HS-grad              9
#
#            marital.status         occupation    relationship   race  sex  ...  \
# 125    Married-civ-spouse       Adm-clerical            Wife  Black    1  ...
# 134    Married-civ-spouse              Sales         Husband  Black    0  ...
# ...

# %%
sns.countplot(x = 'Black', hue = 'income_data', data = workclass_black)
plt.xlabel('Black Race', fontsize = 13)
plt.ylabel('Income', fontsize = 13)
plt.title('Income Black Race', fontsize = 15);

# %%
sns.countplot(x = 'White', hue = 'income_data', data = workclass_white)
plt.xlabel('White Race', fontsize = 13)
plt.ylabel('Income', fontsize = 13)
plt.title('Income White Race', fontsize = 15);

# %%
workclass_white['education'].value_counts()
# Out:
# HS-grad         8394
# Some-college    5702
# Bachelors       4448
# Masters         1458
# Assoc-voc       1142
# 11th             882
# Assoc-acdm       865
# 10th             668
# Prof-school      486
# 7th-8th          475
# 9th              359
# Doctorate        338
# 12th             306
# 5th-6th          242
# 1st-4th          123
# Preschool         33
# Name: education, dtype: int64

# %%
workclass_black['education'].value_counts()
# Out:
# HS-grad         1060
# Some-college     687
# Bachelors        301
# 11th             128
# 10th             119
# Assoc-voc        108
# Assoc-acdm       100
# Masters           78
# 9th               77
# 12th              51
# 7th-8th           49
# 5th-6th           18
# Prof-school       15
# 1st-4th           13
# Doctorate          8
# Preschool          4
# Name: education, dtype: int64

# %%
compare_education_black_white = pd.DataFrame({
    'Education':['Black Education', 'White Education'],
    'Doctorate':[8, 338],
    'Prof-school':[15, 486],
    'Masters':[78, 1458]
})

# %%
compare_education_black_white
# Out:
#          Education  Doctorate  Prof-school  Masters
# 0  Black Education          8           15       78
# 1  White Education        338          486     1458

# %%
compare_education_black_white.plot(kind='barh', x = 'Education')
plt.xlabel('Jumlah Education', fontsize = 15)
plt.ylabel('Race', fontsize = 15)
plt.title('Perbandingan Jumlah Education Black Race dan White Race', fontsize = 20)

plt.savefig('perbandingan jumlah education black race dan white race.png');

# %%
sns.barplot(data = compare_education_black_white)
# Out:
# <AxesSubplot:>

# %%
workclass_black.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income_data', 'Federal-gov', 'Local-gov', 'Private', 'Self-emp-inc',
#        'Self-emp-not-inc', 'State-gov', 'Divorced', 'Married-AF-spouse',
#        'Married-civ-spouse', 'Married-spouse-absent', 'Never-married',
#        'Separated', 'Widowed', 'Amer-Indian-Eskimo', 'Asian-Pac-Islander',
#        'Black', 'Other', 'White'],
#       dtype='object')

# %%
workclass_black['income_data'].value_counts()
# Out:
# 0    2450
# 1     366
# Name: income_data, dtype: int64

# %%
2450+366
# Out:
# 2816

# %%
(366/2816) * 100
# Out:
# 12.997159090909092

# %% [markdown]
# Pajak pendapatan tahun 1995 di amerika 28% untuk pendapatan di atas 50K
#
# 28% dari 50K adalah 14000
#
# jadi orang yang di bawah income 50K kalau di dongkrak jadi:
#
# 2450 x 14000 =
#
#
#
# kalau di bawah 50K pajaknya 16% => 8000
# 2450 x 8000

# %%
2450 * 14000
# Out:
# 34300000

# %%
366 * 14000
# Out:
# 5124000

# %%
2450 * 8000
# Out:
# 19600000

# %%
34300000 - 19600000
# Out:
# 14700000

# %%
workclass_black['hours.per.week'].value_counts()
# Out:
# 40    1624
# 35     163
# 20     118
# 30     113
# 50     101
#       ...
# 3        1
# 5        1
# 13       1
# 51       1
# 62       1
# Name: hours.per.week, Length: 61, dtype: int64

# %%
workclass_black['hours.per.week'].sum()
# Out:
# 108906

# %%
workclass_black.Black.value_counts()
# Out:
# 1    2816
# Name: Black, dtype: int64

# %%
workclass_black['hours.per.week'].value_counts()
# Out:
# 40    1624
# 35     163
# 20     118
# 30     113
# 50     101
#       ...
# 3        1
# 5        1
# 13       1
# 51       1
# 62       1
# Name: hours.per.week, Length: 61, dtype: int64

# %%
b = workclass_black['hours.per.week'].value_counts()

# %%
b.sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Pajak pendapatan tahun 1995 di amerika 28% untuk pendapatan di atas 50K
#
# 28% dari 50K adalah 14000
#
# jadi orang yang di bawah income 50K kalau di dongkrak jadi:
#
# 19082 x 14000
#
#
#
# kalau di bawah 50K pajaknya 16% => 8000
# 6839 x 8000

# %%
workclass_white['income_data'].value_counts()
# Out:
# 0    19082
# 1     6839
# Name: income_data, dtype: int64

# %%
19082 + 6839
# Out:
# 25921

# %%
19082 * 14000
# Out:
# 267148000

# %%
6839 * 8000
# Out:
# 54712000

# %%
267148000 - 54712000
# Out:
# 212436000

# %%
workclass_white['hours.per.week'].value_counts()
# Out:
# 40    11838
# 50     2529
# 45     1637
# 60     1274
# 35      962
#       ...
# 94        1
# 92        1
# 74        1
# 82        1
# 87        1
# Name: hours.per.week, Length: 94, dtype: int64

# %%
w = workclass_white['hours.per.week'].value_counts()

# %%
w.sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
workclass_white['hours.per.week'].sum()
# Out:
# 1068140

# %% [markdown]
# ###

# %% [markdown]
# ### Machine Learning

# %%
X = data_df[['Married-civ-spouse', 'education.num', 'age' , 'hours.per.week', 'capital.gain', 'capital.loss']]
y = data_df['income_data']

#Splitting the data into Train and Test
from sklearn.model_selection import train_test_split 
X_train, X_test,y_train,y_test = train_test_split(X,
                                                y,
                                                test_size = 0.3,
                                                random_state = 42)

# %%
from jupyterthemes import jtplot
jtplot.style(theme='grade3', context='notebook', ticks=True, grid=False, figsize=(20.7,8.27))

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(random_state=42)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Predict the test data
y_predicted = logreg.predict(X_test)
y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_predicted_proba = logreg.predict_proba(X_test)
y_predicted_proba
# Out:
# array([[0.99356725, 0.00643275],
#        [0.90398372, 0.09601628],
#        [0.72291959, 0.27708041],
#        ...,
#        [0.55270646, 0.44729354],
#        [0.93070055, 0.06929945],
#        [0.97095518, 0.02904482]])

# %%
from sklearn.metrics import classification_report, confusion_matrix
print('\nconfustion matrix') # generate the confusion matrix
print(confusion_matrix(y_test, y_predicted))

from sklearn.metrics import accuracy_score
print('\naccuracy')
print(accuracy_score(y_test, y_predicted))

from sklearn.metrics import classification_report
print('\nclassification report')
print(classification_report(y_test, y_predicted)) # generate the precision, recall, f-1 score, num
# Out:
# confustion matrix
# [[5958  881]
#  [ 885 1321]]
#
# accuracy
# 0.8047540077390823
#
# classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      6839
#            1       0.60      0.60      0.60      2206
#
#     accuracy                           0.80      9045
#    macro avg       0.74      0.74      0.74      9045
# weighted avg       0.80      0.80      0.80      9045

# %%
from sklearn.tree import DecisionTreeClassifier

#train
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)

#predict
y_predicted = dt.predict(X_test)

#eval
from sklearn.metrics import classification_report
print('\nclassification report')
print(classification_report(y_test, y_predicted))
# Out:
# classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      6839
#            1       0.68      0.58      0.63      2206
#
#     accuracy                           0.83      9045
#    macro avg       0.77      0.75      0.76      9045
# weighted avg       0.82      0.83      0.83      9045

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_depth=2, random_state=0) # default n_estimator: 100
rf.fit(X, y)

#predict
y_predicted = rf.predict(X_test)

#eval
from sklearn.metrics import classification_report
print('\nclassification report')
print(classification_report(y_test, y_predicted))
# Out:
# classification report
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      6839
#            1       0.98      0.23      0.38      2206
#
#     accuracy                           0.81      9045
#    macro avg       0.89      0.62      0.63      9045
# weighted avg       0.85      0.81      0.76      9045

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
import numpy as np

#List Hyperparameters yang akan diuji
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)] # Number of trees in random forest
max_features = ['auto', 'sqrt'] # Number of features to consider at every split
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)] # Maximum number of levels in tree
max_depth.append(None)
min_samples_split = [2, 5, 10] # Minimum number of samples required to split a node
min_samples_leaf = [1, 2, 4] # Minimum number of samples required at each leaf node
bootstrap = [True, False] # Method of selecting samples for training each tree

#Menjadikan ke dalam bentuk dictionary
hyperparameters = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# Init Logres dengan Gridsearch, cross validation = 5
rf = RandomForestClassifier(random_state=42)
clf = RandomizedSearchCV(rf, hyperparameters, cv=5)

#Fitting Model
best_model = clf.fit(X, y)

#Nilai hyperparameters terbaik
print('Best n_estimators:', best_model.best_estimator_.get_params()['n_estimators'])
print('Best max_depth:', best_model.best_estimator_.get_params()['max_depth'])

#Prediksi menggunakan model baru
y_predicted = best_model.predict(X_test)#Check performa dari model
print(classification_report(y_test, y_predicted))
# roc_auc_score(y_test, y_pred)
# Out:
# Best n_estimators: 800
# Best max_depth: 10
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      6839
#            1       0.82      0.56      0.67      2206
#
#     accuracy                           0.86      9045
#    macro avg       0.85      0.76      0.79      9045
# weighted avg       0.86      0.86      0.85      9045

# %%
feat_importances = pd.Series(dt.feature_importances_, index=X.columns)
ax = feat_importances.nlargest(10).plot(kind='barh')
ax.invert_yaxis()
plt.xlabel('score')
plt.ylabel('feature')
plt.title('feature importance score')
# Out:
# Text(0.5, 1.0, 'feature importance score')

# %%
# get importance
importance = dt.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.28894
# Feature: 1, Score: 0.18747
# Feature: 2, Score: 0.17748
# Feature: 3, Score: 0.12926
# Feature: 4, Score: 0.15783
# Feature: 5, Score: 0.05902

# %% [raw]
# Dari data ini, terlihat bahwa income sangat berpengaruh terhadap pendidikan, dan apabila melihat korelasi antara income dan race terlihat bahwa ada kejomplangan yang sangat jauh antara income orang yang berkulit putih dan berkulit hitam. Hal-hal ini sangat berkorelasi. Apabila kita melihat dengan seksama dari Data Set Sensus Penduduk yang diolah sedemikian rupa ini, terlihat adanya tanda-tanda issus racial di negara america, yang membuat america harus merasakan kondisi yang mencekam pada Juni 2020 ini, terjadi lonjakan demonstrasi masa yang meminta pemerintah lebih adil dan menghapus adanya racial di america, hal ini dipicu ketika kematian salah satu warga sipil america yang bernama George Floyd[1].
#
# [SEJARAH AWAL MULA ADANYA BLM SECARA SINGKAT]
# Kenyataan yang terjadi mengapa issue racial terhadap orang kulit hitam ini dimulai pada abad ke-16 dan 17[2], dimana pada saat itu dimulainya perbudakan terhadap orang kulit hitam oleh kulit putih. Pada Tahun 1955 - 1968 terbentuklah awal dari Gerakan Hak-Hak Sipil Afrika-Amerika dimana ini awal dari BLM atau Black Lives Matters yang sekarang kita kenal, mengacu kepada menghapuskan diskriminasi dari orang-orang kulit hitam.
#
# [LANDASAN KEJOMPLANGAN HASIL PENGOLAHAN DARI DATA SET SENSUS[2]]
# Ada banyak kaum kulit hitam yang telah meraih kesuksesan besar, dari entertainer/pengusaha miliarder seperti Oprah Winfrey dan Jay-Z, sampai politisi-politisi terkemuka seperti Condoleezza Rice, Colin Powell, dan tentunya Barack Obama sebagai Presiden Kulit Hitam AS yang pertama. Namun, mayoritas rakyat kulit hitam hanya menerima sedikit dari pencapaian gerakan hak sipil. Walau di atas kertas mereka setara, tetapi dalam praktik mereka tetap adalah warga kelas dua. Ini bisa kita lihat dari statistik-statistik hari ini.
#
# Sekitar 38 juta warga AS hidup di bawah garis kemiskinan, atau 13,2 persen dari total populasi. Tetapi bagi kaum kulit hitam, situasinya lebih parah. Tingkat kemiskinan untuk populasi kulit hitam adalah 25,3 persen, lebih dari dua kali lipat dibandingkan populasi kulit putih (10,5 persen).
#
# Tingkat pengangguran kulit hitam juga lebih dari dua kali lipat dibandingkan populasi kulit putih, 8,2 persen dibandingkan 3,9 persen menurut data 2007. Bagi mereka yang bekerja, kondisinya tidak lebih baik. Pada 2005, pekerja kulit hitam upahnya hanya 65 persen upah pekerja kulit putih. Angka ini turun dari 85 persen pada 1975.
#
# Yang teramat mencolok adalah kriminalisasi terhadap warga kulit hitam. Amerika Serikat adalah negeri yang tingkat populasi penjaranya paling besar di dunia. Lebih dari 2,2 juta warga AS mendekam di penjara, atau sekitar 655 dari setiap 100.000 orang. Bandingkan dengan Indonesia, 96 per 100.000 orang. Untuk laki-laki kulit hitam, persentase penghuni penjara adalah 4.789 per 100.000, dan untuk kaum muda kulit hitam berumur 25-29 tahun, persentasnya 11.695 per 100.000, yakni 11,7 persen.
#
# [ALASAN DAN FAKTA KENAPA MODELING KITA BENAR DAN DAPAT DI PERTANGGUNG JAWABKAN]
# Karena angka kemiskinan tersebut maka sebagian besar orang yang berkulit hitam tidak dapat merakasakan pendidikan yang tinggi untuk mendorong pendapatan perbulan, yang bisa merasakan pendapatan yang tinggi adalah orang berkulit putih dikarena orang berkulit putih mendapatkan upah yang lebih besar dari orang yang berkulit hitam, hingga akhirnya orang berkuliat putih dapat bersekolah dan mendapatkan pendidikan yang tinggi.
#
#
# BAHAN RUJUKAN
# [1] https://www.kompas.com/global/read/2020/07/09/142225570/bukti-baru-ungkap-kata-terakhir-george-floyd-sebelum-tewas
# [2] https://www.revolusioner.org/internasional/amerika-utara/8793-blacklivesmatter-dan-akar-rasisme-di-amerika-serikat.html
#
# - https://www.liputan6.com/global/read/4266261/rasisme-di-as-lebih-parah-dari-negara-lain-apa-sebabnya
# - https://www.bbc.com/indonesia/dunia-52917132
# - https://www.dw.com/id/pembunuhan-warga-kulit-hitam-yang-guncangkan-as/a-55041261

# %% [raw]
# ==> Lebih menonjolkan hasil pengolahan data set dibandignkan rangkuman berita

# %% [raw]
# https://www.drawingfromdata.com/how-to-rotate-axis-labels-in-seaborn-and-matplotlib
#
# chart = sns.catplot(
#     data=data[data['Year'].isin([1980, 2008])],
#     x='Sport',
#     kind='count',
#     palette='Set1',
#     col='Year',
#     aspect=1,
# )
# chart.set_xticklabels(rotation=65, horizontalalignment='right')
